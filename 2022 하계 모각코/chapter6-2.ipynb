# %%
## 서울열린데이터 광장의 OPEN API를 활용한 공공데이터 수집
# 서울열린데이터 광장 OPEN API에서는 사용자가 요청하는 조건들을 URL주소에 포함해야 함
# http://openapi.seoul.go.kr:8088/{KEY}/{TYPE}/{SERVICE}/{START_INDEX}/{END_INDEX}/{OBJECTID}
import requests # OPEN API 호출을 위함
import pandas as pd

# %%
sgg_pop_df = pd.read_csv('../2022 하계 모각코 자료/6_Starbucks_Location/files/report.txt', sep='\t', header=2)
columns = {
    '기간': 'GIGAN',
    '자치구': 'JACHIGU',
    '계': 'GYE_1',
    '계.1': 'GYE_2',
    '계.2': 'GYE_3',
    '남자': 'NAMJA_1',
    '남자.1': 'NAMJA_2',
    '남자.2': 'NAMJA_3',
    '여자': 'YEOJA_1',
    '여자.1': 'YEOJA_2',
    '여자.2': 'YEOJA_3',
    '세대': 'SEDAE',
    '세대당인구': 'SEDAEDANGINGU',
    '65세이상고령자': 'N_65SEISANGGORYEONGJA'
}
sgg_pop_df.rename(columns = columns, inplace = True)

# %%
sgg_pop_df.head()
# Out:
#       GIGAN JACHIGU      SEDAE      GYE_1    NAMJA_1    YEOJA_1      GYE_2  \
# 0  2020.3/4      합계  4,405,833  9,953,009  4,840,912  5,112,097  9,699,232
# 1  2020.3/4     종로구     74,861    159,842     77,391     82,451    149,952
# 2  2020.3/4      중구     63,594    135,321     66,193     69,128    125,800
# 3  2020.3/4     용산구    112,451    244,953    119,074    125,879    229,786
# 4  2020.3/4     성동구    136,096    302,695    147,582    155,113    295,591
#
#      NAMJA_2    YEOJA_2    GYE_3  NAMJA_3  YEOJA_3  SEDAEDANGINGU  \
# 0  4,719,170  4,980,062  253,777  121,742  132,035           2.20
# 1     73,024     76,928    9,890    4,367    5,523           2.00
# 2     61,526     64,274    9,521    4,667    4,854           1.98
# 3    110,604    119,182   15,167    8,470    6,697           2.04
# 4    144,444    151,147    7,104    3,138    3,966           2.17
#
#   N_65SEISANGGORYEONGJA
# 0             1,552,356
# 1                28,396
# 2                24,265
# ...

# %%
sgg_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GIGAN                  26 non-null     object
#  1   JACHIGU                26 non-null     object
#  2   SEDAE                  26 non-null     object
#  3   GYE_1                  26 non-null     object
#  4   NAMJA_1                26 non-null     object
#  5   YEOJA_1                26 non-null     object
#  6   GYE_2                  26 non-null     object
#  7   NAMJA_2                26 non-null     object
#  8   YEOJA_2                26 non-null     object
#  9   GYE_3                  26 non-null     object
#  10  NAMJA_3                26 non-null     object
#  11  YEOJA_3                26 non-null     object
#  12  SEDAEDANGINGU          26 non-null     float64
#  13  N_65SEISANGGORYEONGJA  26 non-null     object
# dtypes: float64(1), object(13)
# ...

# %%
condition = sgg_pop_df['JACHIGU'] != '합계'
sgg_pop_df_selected = sgg_pop_df[condition]
sgg_pop_df_selected.head()
# Out:
#       GIGAN JACHIGU    SEDAE    GYE_1  NAMJA_1  YEOJA_1    GYE_2  NAMJA_2  \
# 1  2020.3/4     종로구   74,861  159,842   77,391   82,451  149,952   73,024
# 2  2020.3/4      중구   63,594  135,321   66,193   69,128  125,800   61,526
# 3  2020.3/4     용산구  112,451  244,953  119,074  125,879  229,786  110,604
# 4  2020.3/4     성동구  136,096  302,695  147,582  155,113  295,591  144,444
# 5  2020.3/4     광진구  166,857  361,923  174,077  187,846  348,064  168,095
#
#    YEOJA_2   GYE_3 NAMJA_3 YEOJA_3  SEDAEDANGINGU N_65SEISANGGORYEONGJA
# 1   76,928   9,890   4,367   5,523           2.00                28,396
# 2   64,274   9,521   4,667   4,854           1.98                24,265
# 3  119,182  15,167   8,470   6,697           2.04                39,995
# 4  151,147   7,104   3,138   3,966           2.17                45,372
# 5  179,969  13,859   5,982   7,877           2.09                50,047

# %%
sgg_pop_df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GIGAN                  25 non-null     object
#  1   JACHIGU                25 non-null     object
#  2   SEDAE                  25 non-null     object
#  3   GYE_1                  25 non-null     object
#  4   NAMJA_1                25 non-null     object
#  5   YEOJA_1                25 non-null     object
#  6   GYE_2                  25 non-null     object
#  7   NAMJA_2                25 non-null     object
#  8   YEOJA_2                25 non-null     object
#  9   GYE_3                  25 non-null     object
#  10  NAMJA_3                25 non-null     object
#  11  YEOJA_3                25 non-null     object
#  12  SEDAEDANGINGU          25 non-null     float64
#  13  N_65SEISANGGORYEONGJA  25 non-null     object
# dtypes: float64(1), object(13)
# ...

# %%
columns = ['JACHIGU', 'GYE_1']
sgg_pop_df_final = sgg_pop_df_selected[columns]

# %%
sgg_pop_df_final.head()
# Out:
#   JACHIGU    GYE_1
# 1     종로구  159,842
# 2      중구  135,321
# 3     용산구  244,953
# 4     성동구  302,695
# 5     광진구  361,923

# %%
sgg_pop_df_final.columns = ['시군구명', '주민등록인구']
sgg_pop_df_final.head()
# Out:
#   시군구명   주민등록인구
# 1  종로구  159,842
# 2   중구  135,321
# 3  용산구  244,953
# 4  성동구  302,695
# 5  광진구  361,923

# %%
sgg_pop_df_final.to_excel('../2022 하계 모각코 자료/6_Starbucks_Location/files/3_sgg_pop.xlsx', index = False)

# %%
sgg_biz_df = pd.read_csv('../2022 하계 모각코 자료/6_Starbucks_Location/files/report2.txt', sep='\t', header=2)
columns = {
    '기간': 'GIGAN',
    '자치구': 'JACHIGU',
    '동': 'DONG',
    '사업체수': 'SAEOPCHESU_1',
    '여성대표자': 'YEOSEONGDAEPYOJA',
    '계': 'GYE',
    '남': 'NAM',
    '여': 'YEO'
}
sgg_biz_df.rename(columns = columns, inplace = True)
sgg_biz_df.head(10)
# Out:
#    GIGAN JACHIGU         DONG SAEOPCHESU_1 YEOSEONGDAEPYOJA        GYE  \
# 0   2018      합계           합계      823,385          279,711  5,210,936
# 1   2018     종로구           소계       39,952           13,442    265,017
# 2   2018     종로구          사직동        3,541            1,191     49,536
# 3   2018     종로구          삼청동          712              324      4,577
# 4   2018     종로구          부암동          565              240      3,609
# 5   2018     종로구          평창동          751              319      3,565
# 6   2018     종로구          무악동          581              103      1,598
# 7   2018     종로구          교남동          393              156      4,008
# 8   2018     종로구          가회동          766              372     14,100
# 9   2018     종로구  종로1.2.3.4가동       15,603            4,989    109,824
#
#          NAM        YEO 사업체수.1 종사자수  ... 사업체수.15  종사자수.14 사업체수.16  종사자수.15  \
# 0  2,878,227  2,332,709     30  462  ...   1,282  140,121  35,377  346,219
# ...

# %%
condition = sgg_biz_df['DONG'] == '소계'
sgg_biz_df_selected = sgg_biz_df[condition]
sgg_biz_df_selected.head()
# Out:
#     GIGAN JACHIGU DONG SAEOPCHESU_1 YEOSEONGDAEPYOJA      GYE      NAM  \
# 1    2018     종로구   소계       39,952           13,442  265,017  152,717
# 19   2018      중구   소계       60,957           22,669  390,530  210,755
# 35   2018     용산구   소계       20,813            7,153  141,216   76,498
# 52   2018     성동구   소계       27,868            8,432  174,819  100,694
# 70   2018     광진구   소계       24,535            8,948  127,879   69,442
#
#         YEO 사업체수.1 종사자수  ... 사업체수.15 종사자수.14 사업체수.16 종사자수.15 사업체수.17 종사자수.16  \
# 1   112,300      3   17  ...      89  15,658     850  13,504     744  15,888
# 19  179,775      -    -  ...      62  19,280     471   8,321     747  10,104
# 35   64,718      -    -  ...      47   3,149     550   7,452     579   6,658
# 52   74,125      1    3  ...      47   4,471     961  11,371     748   8,539
# 70   58,437      1    3  ...      36   2,662   1,183  14,139     909  11,615
#
#    사업체수.18 종사자수.17 사업체수.19 종사자수.18
# 1      909   6,227   2,448   7,672
# ...

# %%
columns = ['JACHIGU', 'GYE', 'SAEOPCHESU_1']
sgg_biz_df_final = sgg_biz_df_selected[columns]
sgg_biz_df_final.columns = ['시군구명', '종사자수', '사업체수']
sgg_biz_df_final.head()
# Out:
#    시군구명     종사자수    사업체수
# 1   종로구  265,017  39,952
# 19   중구  390,530  60,957
# 35  용산구  141,216  20,813
# 52  성동구  174,819  27,868
# 70  광진구  127,879  24,535

# %%
sgg_biz_df_final = sgg_biz_df_final.reset_index(drop = True)
sgg_biz_df_final.head()
# Out:
#   시군구명     종사자수    사업체수
# 0  종로구  265,017  39,952
# 1   중구  390,530  60,957
# 2  용산구  141,216  20,813
# 3  성동구  174,819  27,868
# 4  광진구  127,879  24,535

# %%
sgg_biz_df_final.to_excel('../2022 하계 모각코 자료/6_Starbucks_Location/files/3_sgg_biz.xlsx', index = False)
