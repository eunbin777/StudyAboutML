# %%
## 지도 시각화

# 데이터 준비
import pandas as pd
raw_total = pd.read_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/1_crawling_raw.xlsx')
raw_total.head()
# Out:
#                                              content        data   like  \
# 0  제주섬에서 또 다른 마을이에요. 약간은 미국 어느한 동네가 생각날 정도로 너무 이국...  2022-08-31    211
# 1  📍듬삭한 제주도 여행오면 오션뷰 찾는 분들 많잖아요? 생각 없이 들어갔다가 너무 맛...  2022-08-31     82
# 2  .💙 생활의달인에 나온 찐맛집 모음집 💙이거슨 찐이다....찐의 기운이 느껴진다.....  2022-08-30  1,194
# 3  서귀포 성산 #신왕 안녕하세요. 우니저입니다🤓네,,,또 중국집이에요,,,😁😁이번에는...  2022-08-31    162
# 4  한번 맛보면 잊을 수 없는 감칠맛과 함께 어마무시한 웨이팅을 뚫고서라고 가야할 제주...  2022-08-29    941
#
#    place                                               tags
# 0  제주도맛집                         ['#후프바베큐바다뷰를', '#푸드빈스_제주']
# 1    NaN  ['#듬삭한', '#제주도맛집', '#제주서쪽맛집', '#제주맛집', '#제주맛집추...
# 2    NaN  ['#삼대국수회관📌제주', '#경미네집📌제주', '#꿉자📌제주', '#성산순덕이네📌...
# 3    NaN  ['#신왕', '#제주도맛집', '#제주맛집', '#제주시맛집', '#서귀포맛집',...
# 4  우진해장국  ['#우진해장국', '#고사리육개장', '#몸국고사리육개장과', '#제주맛집', '...

# %%
# 위치 정보별로 빈도수 집계
location_counts = raw_total['place'].value_counts()
location_counts
# Out:
# 제주도 제주                     78
# 환상의 섬 Jeju Island          33
# South Korea                31
# Jeju-do                    30
# 제주도                        17
#                            ..
# LOTTE HOTEL JEJU 롯데호텔제주     1
# 제주한;양                       1
# 추사 김정희 유배지, 제주도             1
# 저지오름                        1
# 제주인호텔                       1
# Name: place, Length: 354, dtype: int64

# %%
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                    place
# 제주도 제주                78
# 환상의 섬 Jeju Island     33
# South Korea           31
# Jeju-do               30
# 제주도                   17

# %%
location_counts_df.to_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_location_counts.xlsx')

# %%
locations = list(location_counts.index)
locations
# Out:
# ['제주도 제주',
#  '환상의 섬 Jeju Island',
#  'South Korea',
#  'Jeju-do',
#  '제주도',
#  '월정리해변',
#  '사이카레',
#  '제주도 서귀포',
#  '제주도 애월읍',
#  '행복미가',
#  '서울',
#  '제주도 제주시',
#  '푸른섬 제주도',
#  'South Korea & Japan',
#  '김녕 성세기 해변',
#  'Jeju Island',
#  '우도 牛岛 Udo Island, South Korea',
#  '용머리해안',
#  '에코랜드호텔',
#  '대한민국',
#  'South Korea Jeonju',
#  '동문시장 Dongmoon Market 東門水産市場',
#  '스누피가든',
#  '함덕해수욕장',
#  '제주도 곽지해수욕장',
#  '언니네수족관 게스트하우스',
#  'Jeju, Korea',
#  'Seoul, South Korea',
#  '구좌읍 종달리',
#  '신창풍차해안도로',
#  '제주 협재 해수욕장',
#  '금능해수욕장',
#  '제주',
#  'Jeju Island, Korea',
#  'South Korea Gimhae,busan',
#  'Seoul South Korea',
#  '판포포구',
#  '제주피자맛집 보스코화덕피자',
#  'Hamdeok Jeju',
#  '제주도골프장',
#  '애월해안도로',
#  '산지천',
#  'Onrua Jeju',
#  '제주 사계해변',
#  'South Korea Cheongju',
#  'the cliff jeju - 더클리프 제주',
#  '한담해안산책로',
#  '제주아쿠아플라넷',
#  '금악오름',
#  'Pyeongtaek, South Korea',
#  '광치기해변',
#  'South Korea Video',
#  'Jeju Island, South Korea 제주도',
#  '쇠소깍',
#  '제주시 이도이동',
#  '뽀로로타요테마파크 제주',
#  '제주도 표선',
#  'wiee.jeju',
#  '울산 - Ulsan, South Korea',
#  '제주시청 근처',
#  '비밀의숲',
#  '제주 구좌읍 세화리',
#  '사계 해변',
#  'Jungmun Beach',
#  'D&department JEJU by Arario',
#  '종달리 해변',
#  '카페 노티드 제주 애월 - Cafe Knotted Jeju Aewol',
#  'Booyoung Jeju Hotel',
#  '제주 흑돼지 맛집 대박이네',
#  '네꼬야 티하우스',
#  '문도지 오름',
#  'South Korea 한국 우리나라',
#  'South Korean (Seul)',
#  '바나나민박',
#  '협재해수욕장',
#  '제주동문시장',
#  '카페아오오 cafe ooo',
#  '제주삼춘',
#  '사려니숲길',
#  '용두암',
#  '카페치즈태비',
#  'Seongsan Ilchulbong',
#  '협재 수우동',
#  '제주도 하도리',
#  '절물자연휴양림',
#  '우진해장국',
#  'Saeyeon Bridge, Jeju Island',
#  'Maisongladjeju - 메종글래드제주',
#  '하귀초등학교',
#  '순천미향',
#  '제주 용수 성지 - 성 김대건 신부 제주표착 기념성당',
#  '애월하미',
#  '풍로',
#  '몬딱게스트하우스',
#  '반양',
#  '남원바당',
#  '협재이길',
#  '한림항',
#  'HOTEL Toscana',
#  '제노테카',
#  '봉순이네흑돼지',
#  '수목원길 야시장',
#  '휴일로',
#  '내도음악상가',
#  'South Korea Jeollanam-Do Mokpo-Si Sinheung-Dong 868-5',
#  '화방',
#  '후프바베큐',
#  '미깡창고',
#  'Jamsil, Seoul, South Korea',
#  '영국찻집',
#  '제주도 마마롱',
#  '플로우라이크',
#  '삼다공원야간콘서트',
#  'Daegu, South Korea',
#  '방주교회',
#  '버거요',
#  '명단',
#  '흑소랑',
#  '연 과자점',
#  '순심이네한라봉돼지갈비',
#  '피제리아 덤보 Pizzeria Dumbo',
#  '더쏠',
#  'Itaewon Street, Seoul, South Korea',
#  '밀라네사milanesa',
#  'AUBE - 오브',
#  'Fantastic Buger - 판타스틱 버거',
#  '동문재래시장 야시장',
#  'All that JEJU (올댓제주)',
#  'South Korea Jeju Island',
#  '우도온오프',
#  '하나의식탁',
#  '우니스테이',
#  '제주도맛집',
#  '벨진밧',
#  '사진놀이터',
#  '제주 카페 쉼표',
#  '코난비치',
#  '목포여객선터미널',
#  'Gongbech.공백',
#  '도두항',
#  '파더스가든',
#  'Jeongbang Waterfall',
#  'U-do',
#  '뽀로로앤타요 테마파크 제주',
#  '제주도 여행',
#  '제주마방목지',
#  '제주민속촌',
#  '제주시 한림읍 협재리',
#  '서귀포 법환포구',
#  'Oh là là - 올랄라',
#  '카페 마노르블랑 제주',
#  '돌갱이네집',
#  '가파도',
#  '제주도 세화해변',
#  '서귀포시 안덕면',
#  '오누이벌룬',
#  "O'sulloc Tea Museum 오설록티뮤지엄, Jeju, South Korea",
#  '당근말밥 제주',
#  '오조포구',
#  '잠수타기 다이브클럽',
#  '제주게토',
#  '드르쿰다인성산',
#  '세모제주',
#  '제주도 중문색달해변',
#  '남원 큰엉해안',
#  '보라지붕 , 함덕',
#  '제주시 조천읍 선흘리',
#  '플레이스캠프제주',
#  '마라도',
#  '윗세오름(해발 1700M)',
#  '사계해안도로',
#  '휘닉스제주섭지코지',
#  '아날로그우리집',
#  '다인오세아노호텔',
#  '애월해안가',
#  '캠퍼트리호텔앤리조트',
#  '아르떼뮤지엄 Arte Museum',
#  '제주 신창리',
#  '제주공항',
#  '오설록티뮤지엄',
#  '제주무이',
#  '중문색달해변',
#  '김녕해수욕장',
#  '도두해안도로',
#  '우도',
#  '이타프로젝트',
#  '제주신라호텔',
#  'Jeju-Do',
#  'Gwangju, South Korea',
#  '고산리',
#  '빈티지어게인 Vintage Again',
#  '스타벅스 제주성산dt점',
#  '서홍정원',
#  'Salon de Lavant',
#  '서울앵무새 제주점',
#  '한라산아래첫마을',
#  '한담해변',
#  '치앙마이',
#  'CAFE E.P.L',
#  '제주마중',
#  '닭머르',
#  '제주 함덕 서우봉 해변',
#  '파르나스 호텔 제주',
#  'Shilla Stay - 신라스테이',
#  '낙타트래킹',
#  '이호테우해변',
#  '제주유람선',
#  '동백키친',
#  '공공시',
#  '서귀포 쌍둥이 횟집',
#  '파스테이스',
#  '소금바치 순이네',
#  '미스틱 3도',
#  '느루,온穩',
#  '제주도 오설록',
#  'Terrace Room Seoul',
#  '스타벅스 제주용담dt점',
#  'LowHigh',
#  'South Korea Gyeonggi-Do Pyeongtaek-Si Anjung-Ri, Anjung-Eup',
#  '제주도이런날엔',
#  '제주 오광흑돼지',
#  '모슬 포항',
#  '이런날엔',
#  '탑동골목',
#  '제주도 남또리',
#  '명진전복',
#  '서귀포 중문',
#  '흑돼지박스 성산점',
#  '월정리밥집',
#  'Korea',
#  '효돈마을',
#  '공방:하루_반',
#  '수상한집',
#  'South Korea Gyeonggido Gimpo-Si Yanchon Eup',
#  'Hyeopjae Sunset Beach',
#  '부영호텔',
#  'FLOWS JEJU',
#  '돌담통닭',
#  '도토리키친',
#  '옹포리',
#  '숙성도',
#  '브루어스커피',
#  '비양도',
#  '숙성도 중문점',
#  '메르블루게스트하우스',
#  '오드싱',
#  '마루나키친',
#  '우도 하하호호 카페',
#  '스타필드 하남',
#  '강정포구',
#  '제주국제공항',
#  'Gyeongju, South Korea',
#  'Straitgatejeju',
#  '제주특별자치도',
#  '플래닛제주',
#  '제주도 중문해수욕장',
#  '크랩잭',
#  '서귀포호',
#  'Hotel Shalom',
#  '제주성산',
#  '루프탑정원',
#  '효퇴국수',
#  '비자블라썸',
#  '강원도 고성 어느 바닷가',
#  '앞돈지식당',
#  '공천포 식당',
#  '용담동',
#  '송리단길 SongniDan-gil',
#  '부산 해운대',
#  '낭쿰낭쿰',
#  '모슬포 에서',
#  '주상절리대',
#  '구르메스시',
#  '밀림원',
#  '제주베이/Jejubay',
#  '노크온우드',
#  '제주 애월읍',
#  '연돈',
#  '제주도 한림',
#  'YellowDope_Jeju',
#  '황우지선녀탕',
#  '신화워터파크',
#  '아뮤제 - a:musée',
#  '빛의벙커',
#  '만선바다',
#  '색달식당 중문본점',
#  '제주시',
#  '회가서쪽에서뜨겠네',
#  '친봉산장',
#  '제주도 제주특별시',
#  '모알보알',
#  '정곱창',
#  '제주 그 밤',
#  '함덕식탁',
#  '모닥식탁',
#  '제주도 제주시 연동',
#  '대흘리',
#  '제주공항근처',
#  '광주공원 포차 오동도',
#  'Jeju Aqua Planet',
#  '친구집해물포차',
#  '베이커리 우빵',
#  '복닥키친',
#  '모뉴에트',
#  '한림 뽈살집',
#  '삼무곱창',
#  '싱싱잇',
#  '안뜨레제주집',
#  '제주 무릉리',
#  '제주돗',
#  '도치돌목장',
#  '연블링',
#  '도두봉',
#  '히든클리프앤네이처호텔',
#  'Pizzeria Mano',
#  '라니시아 소품샵&카페',
#  '제주시 아라동',
#  '제주도 어딘가',
#  '대중적한우',
#  '올레프로방스',
#  '제주도 서귀포시 성산읍',
#  'Hokkaido',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '용담레포츠공원입구',
#  '이호테우 목마등대',
#  '섭지코지 (Seopjikoji)',
#  '제주 가파도',
#  '포도뮤지엄',
#  '필연',
#  '마인드휘트니스',
#  'Jeju Korea',
#  '제주특별자치도청 / Jeju Special Self-Goverment Province',
#  '제주고산리유적',
#  '법화사 (法華寺)',
#  '카카듀',
#  '포도호텔',
#  '로드129',
#  '허니문하우스',
#  '제주 장인의집',
#  '제주 서귀포',
#  '카페텐저린',
#  '알맞은시간',
#  '만나다공원',
#  '소낭식당',
#  '영육일삼  贏六一三 06/13',
#  '애월리',
#  '서울숲',
#  '중문동',
#  '돌담너머당근',
#  'LOTTE HOTEL JEJU 롯데호텔제주',
#  '제주한;양',
#  '추사 김정희 유배지, 제주도',
#  '저지오름',
#  '제주인호텔']

# %%
# 카카오 로컬 API를 활용한 장소 검색 해보기
from wsgiref import headers
import requests

searching = '합정 스타벅스'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers = {
    "Authorization" : "KakaoAK <카카오API 키>"
}

places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# [{'address_name': '서울 마포구 합정동 472',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '2057327896',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정점',
#   'place_url': 'http://place.map.kakao.com/2057327896',
#   'road_address_name': '서울 마포구 월드컵로1길 14',
#   'x': '126.91253700818196',
#   'y': '37.54994959743763'},
#  {'address_name': '서울 마포구 합정동 473',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '2132676511',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정푸르지오점',
#   'place_url': 'http://place.map.kakao.com/2132676511',
#   'road_address_name': '서울 마포구 월드컵로3길 14',
#   'x': '126.91247704039314',
#   'y': '37.550909116022105'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '288597324',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정폴리스R점',
#   'place_url': 'http://place.map.kakao.com/288597324',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.91340049045',
#   'y': '37.5508989849269'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27076117',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정메세나몰점',
#   'place_url': 'http://place.map.kakao.com/27076117',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.913541853312',
#   'y': '37.5500016943689'},
#  {'address_name': '서울 마포구 서교동 475-13',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '12776689',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 망원역점',
#   'place_url': 'http://place.map.kakao.com/12776689',
#   'road_address_name': '서울 마포구 월드컵로 74',
#   'x': '126.91070575438697',
#   'y': '37.5558452570744'},
#  {'address_name': '서울 마포구 서교동 374-20',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27416913',
#   'phone': '',
#   'place_name': '스타벅스 서교동사거리',
#   'place_url': 'http://place.map.kakao.com/27416913',
#   'road_address_name': '서울 마포구 양화로 105',
#   'x': '126.918607875358',
#   'y': '37.5534723352988'},
#  {'address_name': '서울 마포구 서교동 353-5',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1436512690',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대입구역사거리R점',
#   'place_url': 'http://place.map.kakao.com/1436512690',
#   'road_address_name': '서울 마포구 양화로 125',
#   'x': '126.920317785646',
#   'y': '37.5546231745866'},
#  {'address_name': '서울 마포구 동교동 205-6',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '20705154',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 동교점',
#   'place_url': 'http://place.map.kakao.com/20705154',
#   'road_address_name': '서울 마포구 월드컵북로 22',
#   'x': '126.919993980608',
#   'y': '37.5568646370831'},
#  {'address_name': '서울 마포구 상수동 86-22',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '17127074',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대삼거리점',
#   'place_url': 'http://place.map.kakao.com/17127074',
#   'road_address_name': '서울 마포구 와우산로 64',
#   'x': '126.92328058235611',
#   'y': '37.55025439607592'},
#  {'address_name': '서울 마포구 동교동 159-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '22105109',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대역점',
#   'place_url': 'http://place.map.kakao.com/22105109',
#   'road_address_name': '서울 마포구 양화로 165',
#   'x': '126.923637798148',
#   'y': '37.5572887166274'},
#  {'address_name': '서울 마포구 상수동 329-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26848996',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 상수역점',
#   'place_url': 'http://place.map.kakao.com/26848996',
#   'road_address_name': '서울 마포구 독막로 88',
#   'x': '126.923272022704',
#   'y': '37.5475649101839'},
#  {'address_name': '서울 마포구 동교동 165-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1485627824',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대역8번출구점',
#   'place_url': 'http://place.map.kakao.com/1485627824',
#   'road_address_name': '서울 마포구 양화로 166',
#   'x': '126.924168013515',
#   'y': '37.5567448560452'},
#  {'address_name': '서울 마포구 동교동 166-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '231272664',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대공항철도역점',
#   'place_url': 'http://place.map.kakao.com/231272664',
#   'road_address_name': '서울 마포구 양화로 178',
#   'x': '126.92518582665798',
#   'y': '37.557509550972256'},
#  {'address_name': '서울 마포구 망원동 205-8',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1752574662',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 망원한강공원점',
#   'place_url': 'http://place.map.kakao.com/1752574662',
#   'road_address_name': '',
#   'x': '126.89591772587283',
#   'y': '37.55392483489065'},
#  {'address_name': '서울 마포구 창전동 130',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1572099327',
#   'phone': '',
#   'place_name': '스타벅스 서강광흥창역점',
#   'place_url': 'http://place.map.kakao.com/1572099327',
#   'road_address_name': '서울 마포구 서강로 69',
#   'x': '126.931657893743',
#   'y': '37.5493756625598'}]

# %%
def find_places(searching):
    # 접속 URL 만들기
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

    # headers 입력
    headers = {
        "Authorization": "KakaoAK <카카오API 키>"
    }

    # API 요청 및 정보 받기
    places = requests.get(url, headers = headers).json()['documents']

    # 필요한 정보 선택
    place = places[0]
    name = place['place_name']
    x = place['x']
    y = place['y']
    data = [name, x, y, searching]

    return data

# %%
data = find_places('제주공항')
data
# Out:
# ['제주국제공항', '126.492769004244', '33.5070789578184', '제주공항']

# %%
# 반복작업 진행시 진행바 표시하기위한 라이브러리 tqdm 활용하기
from tqdm.notebook import tqdm

# %%
import time

locations_inform = [ ]

for location in tqdm(locations):
    try:
        data = find_places(location)
        locations_inform.append(data)
        time.sleep(0.5)
    except:
        pass

locations_inform
# Out:
#   0%|          | 0/354 [00:00<?, ?it/s]
# [['제주도', '126.54587355630036', '33.379777816446165', '제주도 제주'],
#  ['PPE', '127.059936935972', '37.5162738482712', 'South Korea'],
#  ['제주도', '126.54587355630036', '33.379777816446165', '제주도'],
#  ['월정리해수욕장', '126.795805057888', '33.556469394054', '월정리해변'],
#  ['사이카레 제주애월본점', '126.381106668339', '33.4842446359284', '사이카레'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51530966206293', '33.23738579332568', '제주도 서귀포'],
#  ['올레길 16코스(고내-광령 올레)', '126.38979561557086', '33.46649759191228', '제주도 애월읍'],
#  ['행복미가', '126.540136968508', '33.4898702994962', '행복미가'],
#  ['북한산둘레길 1구간소나무숲길', '127.00902108350806', '37.65888882945633', '서울'],
#  ['올레길 18코스(제주원도심-조천 올레)',
#   '126.58214303914238',
#   '33.52522810308715',
#   '제주도 제주시'],
#  ['푸른섬게스트하우스', '126.812424476454', '33.3079427982969', '푸른섬 제주도'],
#  ['PPE', '127.059936935972', '37.5162738482712', 'South Korea & Japan'],
#  ['김녕해수욕장', '126.759313988844', '33.5574388587079', '김녕 성세기 해변'],
#  ['제주도', '126.54587355630036', '33.379777816446165', 'Jeju Island'],
#  ['용머리해안', '126.314736627312', '33.2316567556941', '용머리해안'],
#  ['에코랜드호텔', '126.67239369394892', '33.45104914891724', '에코랜드호텔'],
#  ['대한민국', '127.062417480704', '37.5067075025853', '대한민국'],
#  ['스누피가든', '126.779667502934', '33.4433592216395', '스누피가든'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '함덕해수욕장'],
#  ['곽지해수욕장', '126.304673157235', '33.4506575078278', '제주도 곽지해수욕장'],
#  ['성이시돌목장', '126.327321076199', '33.3477698762559', 'Jeju, Korea'],
#  ['용눈이오름', '126.83268298189506', '33.45988023593872', '구좌읍 종달리'],
#  ['신창풍차해안도로', '126.17420604655737', '33.343081026740045', '신창풍차해안도로'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '제주 협재 해수욕장'],
#  ['금능해수욕장', '126.235889902253', '33.3904488156321', '금능해수욕장'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51530966206293', '33.23738579332568', '제주'],
#  ['판포포구', '126.200023263531', '33.365021627537', '판포포구'],
#  ['보스코화덕피자', '126.487859074442', '33.4694461465851', '제주피자맛집 보스코화덕피자'],
#  ['해비치CC 제주', '126.7273091219677', '33.358904572291024', '제주도골프장'],
#  ['애월해안도로', '126.36867872098', '33.4781232943703', '애월해안도로'],
#  ['산지천', '126.527402627066', '33.5133575497499', '산지천'],
#  ['사계해변', '126.3085978558', '33.2286582703756', '제주 사계해변'],
#  ['한담해안산책로', '126.310468326159', '33.4593234504188', '한담해안산책로'],
#  ['아쿠아플라넷 제주', '126.92784588473428', '33.433068041140075', '제주아쿠아플라넷'],
#  ['금오름', '126.30583886304309', '33.354572330015976', '금악오름'],
#  ['광치기해변', '126.92389656873524', '33.45231690975651', '광치기해변'],
#  ['쇠소깍', '126.62240514256442', '33.25424606530691', '쇠소깍'],
#  ['우여천', '126.53688217276', '33.4997396440494', '제주시 이도이동'],
#  ['뽀로로앤타요테마파크 제주', '126.37082203402295', '33.30041822583184', '뽀로로타요테마파크 제주'],
#  ['올레길 4코스(표선-남원 올레)', '126.78792799112594', '33.30481622383354', '제주도 표선'],
#  ['난장게스트하우스', '126.526095975281', '33.5153324500807', '제주시청 근처'],
#  ['비밀의숲', '126.75493209633262', '33.45360917744684', '비밀의숲'],
#  ['세화해변', '126.86025618946', '33.5251436596119', '제주 구좌읍 세화리'],
#  ['사계해변', '126.3085978558', '33.2286582703756', '사계 해변'],
#  ['중문색달해수욕장', '126.411498674889', '33.2450381505136', 'Jungmun Beach'],
#  ['D', '126.734256737675', '37.50793875955', 'D&department JEJU by Arario'],
#  ['종달리해변', '126.90507737845', '33.4886892325511', '종달리 해변'],
#  ['카페노티드 제주애월',
#   '126.30972281394814',
#   '33.46327184686136',
#   '카페 노티드 제주 애월 - Cafe Knotted Jeju Aewol'],
#  ['제주부영호텔앤리조트',
#   '126.42313926057668',
#   '33.2424969120938',
#   'Booyoung Jeju Hotel'],
#  ['돈대박흑돼지오겹살', '126.371473511594', '33.2357287440247', '제주 흑돼지 맛집 대박이네'],
#  ['네꼬야티하우스', '126.41560069922', '33.4856490725031', '네꼬야 티하우스'],
#  ['문도지오름', '126.29461369162291', '33.326250207623005', '문도지 오름'],
#  ['바나나민박', '126.88987288831', '33.521188459532', '바나나민박'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '협재해수욕장'],
#  ['제주동문시장', '126.52830338722843', '33.51278396493313', '제주동문시장'],
#  ['제주삼춘', '126.66733803178', '33.5417978511335', '제주삼춘'],
#  ['사려니숲길', '126.62649730394567', '33.422032834994496', '사려니숲길'],
#  ['용두암', '126.511957109074', '33.5161106216721', '용두암'],
#  ['카페치즈태비', '126.80777194932058', '33.55513706334602', '카페치즈태비'],
#  ['수우동', '126.242439755379', '33.3966233802686', '협재 수우동'],
#  ['올레길 21코스', '126.89827021157316', '33.51281074786431', '제주도 하도리'],
#  ['절물자연휴양림', '126.628011263739', '33.4391525898214', '절물자연휴양림'],
#  ['우진해장국', '126.52000128027187', '33.51151689656457', '우진해장국'],
#  ['하귀초등학교', '126.401941616418', '33.4798137485797', '하귀초등학교'],
#  ['순천미향', '126.3124823832033', '33.23566011965459', '순천미향'],
#  ['애월하미', '126.309145685482', '33.4638853152952', '애월하미'],
#  ['풍로', '126.33308097904708', '33.31002640232977', '풍로'],
#  ['몬딱게스트하우스', '126.852459649813', '33.5192201218977', '몬딱게스트하우스'],
#  ['반양', '126.22616899193866', '33.28120176173073', '반양'],
#  ['남원바당', '126.54283095128335', '33.5030471404792', '남원바당'],
#  ['협재이길', '126.24123686302', '33.3925570800686', '협재이길'],
#  ['한림항', '126.255828967781', '33.4146784560727', '한림항'],
#  ['제노테카', '126.49029168434109', '33.47876693537302', '제노테카'],
#  ['봉순이네흑돼지', '126.27956845026402', '33.27776482008862', '봉순이네흑돼지'],
#  ['수목원길야시장', '126.48788617723713', '33.470142289582924', '수목원길 야시장'],
#  ['휴일로', '126.36652497979144', '33.232208057130535', '휴일로'],
#  ['내도음악상가', '126.44563264281084', '33.49787555711603', '내도음악상가'],
#  ['호미화방', '126.921672541185', '37.5534599921229', '화방'],
#  ['후프바베큐', '126.31061748890217', '33.464395690964615', '후프바베큐'],
#  ['미깡창고', '126.44512769425427', '33.46028056783821', '미깡창고'],
#  ['영국찻집', '126.314112546652', '33.4172313997298', '영국찻집'],
#  ['마마롱', '126.43917783176647', '33.452159287132375', '제주도 마마롱'],
#  ['플로우라이크', '126.930716096922', '33.459953942693', '플로우라이크'],
#  ['방주교회', '126.387439255121', '33.305048981119', '방주교회'],
#  ['버거요 제주본점', '126.29636465588', '33.4464056438579', '버거요'],
#  ['명단', '126.934631213186', '33.4646823066691', '명단'],
#  ['흑소랑', '126.54502505918512', '33.490955830227456', '흑소랑'],
#  ['연과자점', '126.559997555546', '33.2513865187395', '연 과자점'],
#  ['순심이네', '126.33115871455354', '33.246005218922605', '순심이네한라봉돼지갈비'],
#  ['더쏠', '126.41270206249601', '33.261157614569214', '더쏠'],
#  ['밀라네사', '126.590495957529', '33.5097918815577', '밀라네사milanesa'],
#  ['오브', '127.25601375265973', '36.489747055375524', 'AUBE - 오브'],
#  ['제주동문재래야시장', '126.5260173663', '33.5115887463544', '동문재래시장 야시장'],
#  ['온오프', '126.961347021806', '33.5129077956071', '우도온오프'],
#  ['하나의식탁', '126.528960340612', '33.4976108738619', '하나의식탁'],
#  ['우니스테이', '126.651828825434', '33.5489715517006', '우니스테이'],
#  ['원앤온리', '126.319192490757', '33.2392223486155', '제주도맛집'],
#  ['벨진밧', '126.27892937308796', '33.27050226364638', '벨진밧'],
#  ['사진놀이터', '126.441735120785', '33.4567500242143', '사진놀이터'],
#  ['쉼표', '126.24186944438061', '33.39521161644132', '제주 카페 쉼표'],
#  ['코난해변', '126.811202045546', '33.5574549309136', '코난비치'],
#  ['목포연안여객선터미널', '126.3842787613771', '34.782017851535656', '목포여객선터미널'],
#  ['공백', '126.715093661443', '33.5533924123546', 'Gongbech.공백'],
#  ['도두항', '126.466549956171', '33.5073979938833', '도두항'],
#  ['파더스가든', '126.36575317658465', '33.27994207702475', '파더스가든'],
#  ['유캔두잇', '126.898084211952', '37.5262029662293', 'U-do'],
#  ['뽀로로앤타요테마파크 제주',
#   '126.37082203402295',
#   '33.30041822583184',
#   '뽀로로앤타요 테마파크 제주'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51530966206293', '33.23738579332568', '제주도 여행'],
#  ['마방목지', '126.60359603464576', '33.42763738125047', '제주마방목지'],
#  ['제주민속촌', '126.842297283809', '33.3223959546448', '제주민속촌'],
#  ['협재해수욕장', '126.239157539085', '33.3938660776221', '제주시 한림읍 협재리'],
#  ['법환포구', '126.515606477986', '33.2372607213758', '서귀포 법환포구'],
#  ['돌갱이네집', '126.23982665269988', '33.39367633676848', '돌갱이네집'],
#  ['가파도', '126.27141034691293', '33.170012123095724', '가파도'],
#  ['세화해변', '126.86025618946', '33.5251436596119', '제주도 세화해변'],
#  ['올레길 9코스(대평-화순 올레)', '126.3483591501524', '33.242674889021984', '서귀포시 안덕면'],
#  ['오누이벌룬', '126.425818079292', '33.4885828169759', '오누이벌룬'],
#  ['당근말밥제주', '126.51324070212', '33.5040884597474', '당근말밥 제주'],
#  ['오조포구', '126.921029929782', '33.4632498460078', '오조포구'],
#  ['잠수타기다이브클럽', '126.561594416164', '33.2419106102302', '잠수타기 다이브클럽'],
#  ['제주게토게스트하우스파티', '126.71328029582692', '33.29958933840072', '제주게토'],
#  ['드르쿰다in성산', '126.91908094568531', '33.444502297886025', '드르쿰다인성산'],
#  ['세모', '126.808174862569', '33.5531100021514', '세모제주'],
#  ['중문색달해수욕장', '126.411498674889', '33.2450381505136', '제주도 중문색달해변'],
#  ['남원큰엉해변', '126.703710044663', '33.2733501754907', '남원 큰엉해안'],
#  ['보라지붕', '126.670152099835', '33.5407595316729', '보라지붕 , 함덕'],
#  ['거문오름', '126.7147426892805', '33.45692228643522', '제주시 조천읍 선흘리'],
#  ['플레이스캠프제주', '126.91820900260372', '33.4499438543169', '플레이스캠프제주'],
#  ['마라도', '126.267165665899', '33.118480912949', '마라도'],
#  ['형제해안도로', '126.293352563779', '33.2167542093081', '사계해안도로'],
#  ['휘닉스제주', '126.92821246692917', '33.430587011950045', '휘닉스제주섭지코지'],
#  ['아날로그우리집', '126.635772807017', '33.5385426405824', '아날로그우리집'],
#  ['다인오세아노호텔', '126.3504708281553', '33.4724871676714', '다인오세아노호텔'],
#  ['캠퍼트리 호텔앤리조트', '126.448882443633', '33.4530268599999', '캠퍼트리호텔앤리조트'],
#  ['아르떼뮤지엄 제주',
#   '126.34501060259869',
#   '33.39670048068425',
#   '아르떼뮤지엄 Arte Museum'],
#  ['신창풍차해안도로', '126.17420604655737', '33.343081026740045', '제주 신창리'],
#  ['제주국제공항', '126.492769004244', '33.5070789578184', '제주공항'],
#  ['오설록티뮤지엄', '126.28948929546861', '33.30591328662081', '오설록티뮤지엄'],
#  ['제주무이', '126.38808848579211', '33.469092965338206', '제주무이'],
#  ['중문색달해수욕장', '126.411498674889', '33.2450381505136', '중문색달해변'],
#  ['김녕해수욕장', '126.759313988844', '33.5574388587079', '김녕해수욕장'],
#  ['도두동무지개해안도로', '126.471338444636', '33.5091180133618', '도두해안도로'],
#  ['우도', '126.955582257582', '33.5044199749505', '우도'],
#  ['이타프로젝트', '126.546460517776', '33.4756745370693', '이타프로젝트'],
#  ['제주신라호텔', '126.40804141124566', '33.24743087763671', '제주신라호텔'],
#  ['고산천', '127.215873596531', '37.373839874777', '고산리'],
#  ['스타벅스 제주성산DT점', '126.920676533644', '33.4496930061935', '스타벅스 제주성산dt점'],
#  ['서홍정원', '126.554407157697', '33.2525711912172', '서홍정원'],
#  ['살롱드라방', '126.348969735405', '33.4578582644197', 'Salon de Lavant'],
#  ['서울앵무새 제주점', '126.416637918507', '33.2696513679579', '서울앵무새 제주점'],
#  ['한라산아래첫마을', '126.37954963795777', '33.32820916398474', '한라산아래첫마을'],
#  ['한담해변', '126.310182891852', '33.462224964007', '한담해변'],
#  ['치앙마이방콕', '127.437748947247', '36.3341464526663', '치앙마이'],
#  ['카페이피엘', '126.656989843032', '33.2751811821941', 'CAFE E.P.L'],
#  ['제주마중', '126.230307153455', '33.3892711022926', '제주마중'],
#  ['닭머르', '126.61189693619232', '33.53647489410832', '닭머르'],
#  ['함덕해수욕장', '126.669238934013', '33.5430615661113', '제주 함덕 서우봉 해변'],
#  ['파르나스호텔 제주', '126.405763242364', '33.2445934288837', '파르나스 호텔 제주'],
#  ['신라스테이 해운대', '129.158738391647', '35.1597975116785', 'Shilla Stay - 신라스테이'],
#  ['낙타트래킹', '126.778643630857', '33.4026982602717', '낙타트래킹'],
#  ['이호테우해수욕장', '126.452690819027', '33.4973768007144', '이호테우해변'],
#  ['제주크루즈', '126.46539980009214', '33.506467105333094', '제주유람선'],
#  ['동백키친', '126.267001342656', '33.4284743326471', '동백키친'],
#  ['공공시', '126.543670685399', '33.5017582536497', '공공시'],
#  ['쌍둥이횟집', '126.562927484565', '33.2465677180323', '서귀포 쌍둥이 횟집'],
#  ['파스테이스', '126.26684862529', '33.4076260320448', '파스테이스'],
#  ['소금바치순이네', '126.91263326000902', '33.50365240929026', '소금바치 순이네'],
#  ['미스틱3도', '126.487556300468', '33.4499469794883', '미스틱 3도'],
#  ['오설록티뮤지엄', '126.28948929546861', '33.30591328662081', '제주도 오설록'],
#  ['스타벅스 제주용담DT점', '126.484480056159', '33.5124867330564', '스타벅스 제주용담dt점'],
#  ['로우하이카페', '126.339012888564', '33.4633683680655', 'LowHigh'],
#  ['이런날엔', '126.8306579838234', '33.54253281448956', '제주도이런날엔'],
#  ['제주오광흑돼지', '126.250620058101', '33.2199330196962', '제주 오광흑돼지'],
#  ['모슬포항', '126.250509085028', '33.2164674474575', '모슬 포항'],
#  ['이런날엔', '126.8306579838234', '33.54253281448956', '이런날엔'],
#  ['제주탑동골목', '126.52608303980253', '33.51533600695393', '탑동골목'],
#  ['남또리횟집', '126.349344217841', '33.4728085344377', '제주도 남또리'],
#  ['명진전복', '126.850184971014', '33.5324709034017', '명진전복'],
#  ['중문대포주상절리대', '126.42601744245376', '33.23799399299591', '서귀포 중문'],
#  ['흑돼지박스', '126.92041117686354', '33.43640667631552', '흑돼지박스 성산점'],
#  ['월정리밥집', '126.79567007516104', '33.55525652739', '월정리밥집'],
#  ['ITCS KOREA', '126.837852623984', '37.5311524042719', 'Korea'],
#  ['하효마을회관', '126.618944911752', '33.2622600318158', '효돈마을'],
#  ['수상한 집', '126.58711458685292', '33.508145167099514', '수상한집'],
#  ['제주부영호텔앤리조트', '126.42313926057668', '33.2424969120938', '부영호텔'],
#  ['돌담통닭', '126.862202516483', '33.523748360496', '돌담통닭'],
#  ['도토리키친 본점', '126.51860434812481', '33.51538650964344', '도토리키친'],
#  ['해안도로입구 옹포귀덕', '126.254341199384', '33.4071142226903', '옹포리'],
#  ['숙성도 노형점', '126.48502796132595', '33.48503198254993', '숙성도'],
#  ['브루어스커피', '127.156074573876', '36.8174746419808', '브루어스커피'],
#  ['비양도', '126.227348369237', '33.4102777124648', '비양도'],
#  ['숙성도 중문점', '126.4075053251621', '33.2583379388495', '숙성도 중문점'],
#  ['메르블루 게스트하우스', '126.89406023128379', '33.522036009795436', '메르블루게스트하우스'],
#  ['오드싱오름', '126.520000078645', '33.4699985210507', '오드싱'],
#  ['마루나키친', '126.19578600014688', '33.361941471094404', '마루나키친'],
#  ['하하호호 우도본점', '126.94847055953139', '33.52082638555345', '우도 하하호호 카페'],
#  ['스타필드 하남', '127.223691197241', '37.5454930733426', '스타필드 하남'],
#  ['강정포구', '126.475561352176', '33.2271155064362', '강정포구'],
#  ['제주국제공항', '126.492769004244', '33.5070789578184', '제주국제공항'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51530966206293', '33.23738579332568', '제주특별자치도'],
#  ['플래닛제주', '126.490573791441', '33.4901236542942', '플래닛제주'],
#  ['중문색달해수욕장', '126.411498674889', '33.2450381505136', '제주도 중문해수욕장'],
#  ['크랩잭 제주', '126.381855115396', '33.485514197938', '크랩잭'],
#  ['서귀포호', '126.55917430088292', '33.249500999901855', '서귀포호'],
#  ['올레길 1코스(시흥-광치기 올레)', '126.90636648646604', '33.47866074455451', '제주성산'],
#  ['루프탑해오름정원', '126.891386974047', '37.5230777283802', '루프탑정원'],
#  ['효퇴국수', '126.51960543996081', '33.50154015955687', '효퇴국수'],
#  ['비자블라썸', '126.8089704294791', '33.494936462096156', '비자블라썸'],
#  ['앞돈지', '126.527517158494', '33.5160483318116', '앞돈지식당'],
#  ['공천포식당', '126.642586419037', '33.2663875765224', '공천포 식당'],
#  ['용연계곡', '126.51443095406', '33.512764627078', '용담동'],
#  ['해운대해수욕장', '129.159854668484', '35.1585232170784', '부산 해운대'],
#  ['낭쿰낭쿰', '126.56075128691', '33.2517318025358', '낭쿰낭쿰'],
#  ['모슬포에서', '126.25491619909934', '33.22195409384925', '모슬포 에서'],
#  ['중문대포주상절리대', '126.42601744245376', '33.23799399299591', '주상절리대'],
#  ['구루메스시', '127.02353498939178', '37.51051668092548', '구르메스시'],
#  ['밀림원', '126.653887178231', '33.4820428593581', '밀림원'],
#  ['노크온우드', '128.597850717156', '35.86300004843', '노크온우드'],
#  ['올레길 16코스(고내-광령 올레)', '126.38979561557086', '33.46649759191228', '제주 애월읍'],
#  ['연돈', '126.40715814631936', '33.258895288625645', '연돈'],
#  ['올레길 14코스(저지-한림 올레)', '126.22960827746336', '33.36565953780862', '제주도 한림'],
#  ['황우지선녀탕', '126.548890040858', '33.2394632379095', '황우지선녀탕'],
#  ['신화워터파크', '126.31539853510586', '33.306074062116124', '신화워터파크'],
#  ['빛의 벙커', '126.89981394705958', '33.43964657077559', '빛의벙커'],
#  ['만선바다', '126.489294768925', '33.490976705069', '만선바다'],
#  ['색달식당 중문갈치조림구이 본점', '126.38624441353717', '33.24181180984976', '색달식당 중문본점'],
#  ['올레길 18코스(제주원도심-조천 올레)', '126.58214303914238', '33.52522810308715', '제주시'],
#  ['회가서쪽에서뜨겠네', '126.31157305614', '33.4599967624151', '회가서쪽에서뜨겠네'],
#  ['친봉산장', '126.596072341382', '33.2911373041463', '친봉산장'],
#  ['우도특별시', '126.967002230802', '33.50671361571', '제주도 제주특별시'],
#  ['모알보알 제주', '126.727953094591', '33.5595665887276', '모알보알'],
#  ['제주정곱창', '126.492485819933', '33.4862618659799', '정곱창'],
#  ['제주그밤', '126.274877222833', '33.4366565361751', '제주 그 밤'],
#  ['함덕식탁', '126.672227699664', '33.541955145237', '함덕식탁'],
#  ['모닥식탁', '126.81735720624931', '33.5309608434844', '모닥식탁'],
#  ['한라수목원', '126.493266082832', '33.4697839260314', '제주도 제주시 연동'],
#  ['세미오름', '126.66942177756202', '33.474047489006026', '대흘리'],
#  ['선물고팡 제주공항점', '126.50493234736214', '33.50297002454212', '제주공항근처'],
#  ['아쿠아플라넷 제주', '126.92784588473428', '33.433068041140075', 'Jeju Aqua Planet'],
#  ['친구집해물포차', '126.434041649339', '33.4891282412302', '친구집해물포차'],
#  ['베이커리우빵', '126.53448043250907', '33.49889396570024', '베이커리 우빵'],
#  ['복닥키친', '126.478830055555', '33.4775462975962', '복닥키친'],
#  ['모뉴에트', '126.902224926828', '33.4914819914411', '모뉴에트'],
#  ['뽈살집 한림점', '126.26924628540898', '33.41566160720984', '한림 뽈살집'],
#  ['삼무곱창 흑돼지 연동점', '126.490678597673', '33.4896823050931', '삼무곱창'],
#  ['싱싱잇', '126.227275495378', '33.3864501267467', '싱싱잇'],
#  ['안뜨레제주집', '126.510716685616', '33.2537197409979', '안뜨레제주집'],
#  ['영락리 방파제', '126.193888238804', '33.2529892310521', '제주 무릉리'],
#  ['제주돗', '126.23090531024278', '33.33314528305624', '제주돗'],
#  ['도치돌목장', '126.365809643225', '33.4099556021011', '도치돌목장'],
#  ['연블링', '126.528791250845', '33.508162463531', '연블링'],
#  ['도두봉', '126.46835013387586', '33.50798635475609', '도두봉'],
#  ['히든클리프호텔 앤 네이쳐 치치라운지',
#   '126.402667390264',
#   '33.2548814236002',
#   '히든클리프앤네이처호텔'],
#  ['핏제리아 마노', '126.429191724439', '33.4844249480885', 'Pizzeria Mano'],
#  ['한라산국립공원', '126.54222094512', '33.3766655632143', '제주시 아라동'],
#  ['어디가맨 성산점', '126.913247914755', '33.4441341031852', '제주도 어딘가'],
#  ['대중적한우', '126.634758568727', '37.4495726317794', '대중적한우'],
#  ['제주올레프로방스', '126.43420192583064', '33.43002054077319', '올레프로방스'],
#  ['올레길 1코스(시흥-광치기 올레)',
#   '126.90636648646604',
#   '33.47866074455451',
#   '제주도 서귀포시 성산읍'],
#  ['홋카이도', '126.4843904761002', '33.48584527284318', 'Hokkaido'],
#  ['용담체육공원', '126.498886046896', '33.5183304371413', '용담레포츠공원입구'],
#  ['이호테우등대', '126.451961352582', '33.5017949651276', '이호테우 목마등대'],
#  ['섭지코지', '126.930609241011', '33.4239380655993', '섭지코지 (Seopjikoji)'],
#  ['가파도', '126.27141034691293', '33.170012123095724', '제주 가파도'],
#  ['포도뮤지엄', '126.385969459857', '33.3192727556025', '포도뮤지엄'],
#  ['필연', '126.69526168025456', '33.48191347366597', '필연'],
#  ['마인드휘트니스 제주공항점', '126.49312379193137', '33.495695127390015', '마인드휘트니스'],
#  ['성이시돌목장', '126.327321076199', '33.3477698762559', 'Jeju Korea'],
#  ['제주고산리유적', '126.1666521275124', '33.30508436596465', '제주고산리유적'],
#  ['카카듀', '126.541769240624', '33.4913116842266', '카카듀'],
#  ['포도호텔', '126.387456776353', '33.3178988308951', '포도호텔'],
#  ['로드129', '126.321048106969', '33.4643081022978', '로드129'],
#  ['허니문하우스', '126.578712696609', '33.244155324551', '허니문하우스'],
#  ['장인의집', '126.326837162725', '33.4657424492049', '제주 장인의집'],
#  ['올레길 7코스(서귀포-월평 올레)', '126.51530966206293', '33.23738579332568', '제주 서귀포'],
#  ['텐저린카페', '126.50870672572', '33.2362671146571', '카페텐저린'],
#  ['알맞은시간', '126.76910482400906', '33.3065156071006', '알맞은시간'],
#  ['만나다공원', '126.672305399928', '33.5133675897688', '만나다공원'],
#  ['소낭식당', '126.676336466249', '33.5338227626967', '소낭식당'],
#  ['한담해변', '126.310182891852', '33.462224964007', '애월리'],
#  ['서울숲', '127.037617759165', '37.5443222301513', '서울숲'],
#  ['제주중문관광단지', '126.420734158755', '33.2458352639585', '중문동'],
#  ['돌담너머당근', '126.838269613651', '33.5364797483225', '돌담너머당근'],
#  ['롯데시티호텔 제주',
#   '126.486477218467',
#   '33.4906945837847',
#   'LOTTE HOTEL JEJU 롯데호텔제주'],
#  ['제주한양', '126.503747406778', '33.2530375445232', '제주한;양'],
#  ['제주추사관', '126.278221336275', '33.2499729906705', '추사 김정희 유배지, 제주도'],
#  ['저지오름', '126.250860111101', '33.3326866123772', '저지오름'],
#  ['오드리인호텔', '126.46018407392755', '33.503053617025486', '제주인호텔']]

# %%
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['카카오위치명', '경도', '위도', '인스타위치명']
locations_inform_df.to_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_locations.xlsx', index = False)

# %%
location_counts_df = pd.read_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_location_counts.xlsx', index_col = 0)
locations_inform_df = pd.read_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_locations.xlsx')

# %%
location_data = pd.merge(locations_inform_df, location_counts_df,
                        # inner로 양쪽 모두 있는 데이터만 포함
                        # 왼쪽에 위치한 데이터에서 해당 칼럼을 기준으로 병합
                        # 오른쪽에 위치한 데이터에서 인덱스를 기준으로 병합
                        how = 'inner', left_on = '카카오위치명', right_index = True)
location_data.head()
# Out:
#     카카오위치명          경도         위도       인스타위치명  place
# 0      제주도  126.545874  33.379778       제주도 제주     17
# 2      제주도  126.545874  33.379778          제주도     17
# 13     제주도  126.545874  33.379778  Jeju Island     17
# 7     행복미가  126.540137  33.489870         행복미가      8
# 12  김녕해수욕장  126.759314  33.557439    김녕 성세기 해변      1

# %%
location_data['카카오위치명'].value_counts()
# Out:
# 제주도         3
# 협재해수욕장      3
# 신창풍차해안도로    2
# 이런날엔        2
# 한담해변        2
#            ..
# 방주교회        1
# 플로우라이크      1
# 영국찻집        1
# 미깡창고        1
# 저지오름        1
# Name: 카카오위치명, Length: 126, dtype: int64

# %%
location_data = location_data.pivot_table(index = ['카카오위치명', '경도', '위도'], values = 'place', aggfunc = 'sum')
location_data.head()
# Out:
#                              place
# 카카오위치명 경도         위도
# 가파도    126.271410 33.170012      2
# 강정포구   126.475561 33.227116      1
# 공공시    126.543671 33.501758      1
# 광치기해변  126.923897 33.452317      2
# 금능해수욕장 126.235890 33.390449      3

# %%
location_data.to_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_location_inform.xlsx')

# %%
location_data = pd.read_excel('../2022 하계 모각코 자료/5_Jeju_Hotplace/files/3_location_inform.xlsx')
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   카카오위치명  126 non-null    object
#  1   경도      126 non-null    float64
#  2   위도      126 non-null    float64
#  3   place   126 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.1+ KB

# %%
# %pip install folium
# Out:
# Collecting foliumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\keb20\anaconda3\lib\site-packages (from folium) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\keb20\anaconda3\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: numpy in c:\users\keb20\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\keb20\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\keb20\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\keb20\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\keb20\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\keb20\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1

# %%
# 위치 정보 데이터를 지도에 표시할 수 있게 해주는 라이브러리
import folium

Mt_Hanla = [33.362500, 126.533694]
# 지도를 생성하는 명령어 folium.Map
# location 옵션으로 지도의 중심을 지정
map_jeju = folium.Map(location = Mt_Hanla, zoom_start = 11)

for i in range(len(location_data)):
    name = location_data['카카오위치명'][i]
    count = location_data['place'][i]
    size = int(count) * 5
    long = float(location_data['위도'][i])
    lat = float(location_data['경도'][i])
    folium.CircleMarker((long, lat), radius = size, color = 'red', popup = name).add_to(map_jeju)

map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c9bce0a6c542726eed3c2794375877 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c9bce0a6c542726eed3c2794375877&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_94c9bce0a6c542726eed3c2794375877 = L.map(
#                 &quot;map_94c9bce0a6c542726eed3c2794375877&quot;,
#                 {
#                     center: [33.3625, 126.533694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46dfdd8b196344f29ab217bb9c798455 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94c9bce0a6c542726eed3c2794375877);
#
#
#             var circle_marker_b1d2ff19bf3d61c7d2a1fb4a94beffa5 = L.circleMarker(
#                 [33.17001212309572, 126.2714103469129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94c9bce0a6c542726eed3c2794375877);
#
#
#         var popup_3f675ea36b1bfb9c64af3fecec08d03b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_56a7f0004e9363d9c2eb81b4e0d65d21 = $(`&lt;div id=&quot;html_56a7f0004e9363d9c2eb81b4e0d65d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가파도&lt;/div&gt;`)[0];
#             popup_3f675ea36b1bfb9c64af3fecec08d03b.setContent(html_56a7f0004e9363d9c2eb81b4e0d65d21);
#
#
#         circle_marker_b1d2ff19bf3d61c7d2a1fb4a94beffa5.bindPopup(popup_3f675ea36b1bfb9c64af3fecec08d03b)
#         ;
#
#
#
#
#             var circle_marker_bb2f93ffecc65dec50096ef1f90cd6de = L.circleMarker(
#                 [33.2271155064362, 126.475561352176],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94c9bce0a6c542726eed3c2794375877);
#
#
#         var popup_a1f6e747d3f38ce6c0a66e9ce7c71231 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7883677d3f6e1b1a9ad05fcb1dfe6873 = $(`&lt;div id=&quot;html_7883677d3f6e1b1a9ad05fcb1dfe6873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강정포구&lt;/div&gt;`)[0];
#             popup_a1f6e747d3f38ce6c0a66e9ce7c71231.setContent(html_7883677d3f6e1b1a9ad05fcb1dfe6873);
#
#
#         circle_marker_bb2f93ffecc65dec50096ef1f90cd6de.bindPopup(popup_a1f6e747d3f38ce6c0a66e9ce7c71231)
#         ;
#
#
#
#
#             var circle_marker_f7283f6c2788cb7cc16630bf9dfd9b0a = L.circleMarker(
#                 [33.5017582536497, 126.543670685399],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94c9bce0a6c542726eed3c2794375877);
#
#
#         var popup_2bd470d39c4d5e74b49c94bb29118b82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d52f5fb486b8e5156292f4bd7f2bc78e = $(`&lt;div id=&quot;html_d52f5fb486b8e5156292f4bd7f2bc78e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;공공시&lt;/div&gt;`)[0];
#             popup_2bd470d39c4d5e74b49c94bb29118b82.setContent(html_d52f5fb486b8e5156292f4bd7f2bc78e);
#
#
#         circle_marker_f7283f6c2788cb7cc16630bf9dfd9b0a.bindPopup(popup_2bd470d39c4d5e74b49c94bb29118b82)
#         ;
#
#
#
#
#             var circle_marker_78294686b3172fc702ecd8a6d2fbfdd9 = L.circleMarker(
#                 [33.45231690975651, 126.9238965687352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;
